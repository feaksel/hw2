# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load MNIST dataset
transform = transforms.Compose([transforms.ToTensor()])
train_dataset = datasets.MNIST(root='./data', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='./data', train=False, transform=transform, download=True)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=1000, shuffle=False)

# %%
#Var1    
model = DeeperCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_losses, test_losses = [], []
train_accuracies, test_accuracies = [], []

for epoch in range(10):
    train_loss, train_acc = train(model, device, train_loader, optimizer, criterion)
    test_loss, test_acc = evaluate(model, device, test_loader, criterion)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}%, Test Acc={test_acc:.2f}%")

#Plotting
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch"), plt.ylabel("Loss"), plt.title("Loss Curve")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label="Train Acc")
plt.plot(test_accuracies, label="Test Acc")
plt.xlabel("Epoch"), plt.ylabel("Accuracy (%)"), plt.title("Accuracy Curve")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1: Train Acc=91.13%, Test Acc=98.40%
# Epoch 2: Train Acc=97.48%, Test Acc=98.69%
# Epoch 3: Train Acc=98.19%, Test Acc=99.03%
# Epoch 4: Train Acc=98.49%, Test Acc=99.06%
# Epoch 5: Train Acc=98.75%, Test Acc=99.25%
# Epoch 6: Train Acc=98.92%, Test Acc=99.27%
# Epoch 7: Train Acc=99.11%, Test Acc=99.13%
# Epoch 8: Train Acc=99.24%, Test Acc=99.24%
# Epoch 9: Train Acc=99.24%, Test Acc=99.33%
# Epoch 10: Train Acc=99.38%, Test Acc=99.22%

# %% [markdown]
# This model got to high accuracy faster but made more errors as it gone on.

# %%
#Var2    
model = KernelSizeCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_losses, test_losses = [], []
train_accuracies, test_accuracies = [], []

for epoch in range(10):
    train_loss, train_acc = train(model, device, train_loader, optimizer, criterion)
    test_loss, test_acc = evaluate(model, device, test_loader, criterion)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}%, Test Acc={test_acc:.2f}%")

#Plotting
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch"), plt.ylabel("Loss"), plt.title("Loss Curve")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label="Train Acc")
plt.plot(test_accuracies, label="Test Acc")
plt.xlabel("Epoch"), plt.ylabel("Accuracy (%)"), plt.title("Accuracy Curve")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1: Train Acc=87.12%, Test Acc=96.97%
# Epoch 2: Train Acc=95.15%, Test Acc=97.82%
# Epoch 3: Train Acc=96.22%, Test Acc=98.22%
# Epoch 4: Train Acc=96.81%, Test Acc=98.26%
# Epoch 5: Train Acc=97.17%, Test Acc=98.29%
# Epoch 6: Train Acc=97.30%, Test Acc=98.32%
# Epoch 7: Train Acc=97.59%, Test Acc=98.56%
# Epoch 8: Train Acc=97.79%, Test Acc=98.67%
# Epoch 9: Train Acc=97.95%, Test Acc=98.57%
# Epoch 10: Train Acc=98.06%, Test Acc=98.55%

# %% [markdown]
# This model performed well but our baseline was slightly better at accuracy and error evasion.

# %%
#Var3    
model = BNLeakyCNN().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

train_losses, test_losses = [], []
train_accuracies, test_accuracies = [], []

for epoch in range(10):
    train_loss, train_acc = train(model, device, train_loader, optimizer, criterion)
    test_loss, test_acc = evaluate(model, device, test_loader, criterion)
    train_losses.append(train_loss)
    test_losses.append(test_loss)
    train_accuracies.append(train_acc)
    test_accuracies.append(test_acc)
    print(f"Epoch {epoch+1}: Train Acc={train_acc:.2f}%, Test Acc={test_acc:.2f}%")
    
#Plotting
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.xlabel("Epoch"), plt.ylabel("Loss"), plt.title("Loss Curve")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label="Train Acc")
plt.plot(test_accuracies, label="Test Acc")
plt.xlabel("Epoch"), plt.ylabel("Accuracy (%)"), plt.title("Accuracy Curve")
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1: Train Acc=93.59%, Test Acc=98.44%
# Epoch 2: Train Acc=97.28%, Test Acc=98.73%
# Epoch 3: Train Acc=97.92%, Test Acc=98.71%
# Epoch 4: Train Acc=98.32%, Test Acc=98.93%
# Epoch 5: Train Acc=98.47%, Test Acc=99.05%
# Epoch 6: Train Acc=98.75%, Test Acc=99.06%
# Epoch 7: Train Acc=98.91%, Test Acc=98.77%
# Epoch 8: Train Acc=99.02%, Test Acc=99.14%
# Epoch 9: Train Acc=99.12%, Test Acc=99.20%
# Epoch 10: Train Acc=99.21%, Test Acc=99.16%

# %% [markdown]
# This model got to the our baseline performance slower but it got wavy results in training accuracy at 5th epoch.
